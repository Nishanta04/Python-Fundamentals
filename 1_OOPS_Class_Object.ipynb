# %% [markdown]
# <a href="https://colab.research.google.com/github/Nishanta04/Python-Fundamentals/blob/main/1_OOPS_Class_Object.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
L = [1,2,3]
L.upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1139/2270488342.py in <cell line: 0>()
#       1 L = [1,2,3]
# ----> 2 L.upper()
#
# AttributeError: 'list' object has no attribute 'upper'

# %%
s = "hello"
s.append('x')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1139/1278136958.py in <cell line: 0>()
#       1 s = "hello"
# ----> 2 s.append('x')
#
# AttributeError: 'str' object has no attribute 'append'

# %% [markdown]
# This states that everything in python is an object

# %% [markdown]
# - Object is an instance of a class
# - All the datatypes in python are classes and when we make a variable of a specific datatype then that variable is the object of that specific class.

# %%
L = [1, 2, 3]
print(type(L))
# here L is the object of class list
# Out:
# <class 'list'>

# %%
# synatax to create an object
# objectname = classname()

# %%
# object literals
L = list()
s = str()
L
# Out:
# []

# %% [markdown]
# ATM Machine Code

# %%
class Atm:
  # constructor(special function) -> Superpower -> methods automatically called when object is created
  def __init__(self):
    self.pin = ''
    self.balance = 0
    self.menu()

  def menu(self):
    user_input = input("""
    Hi how can I help you?
    1. Press 1 to create pin
    2. Press 2 to change pin
    3. Press 3 to check balance
    4. Press 4 to withdraw
    5. Anything else to exit
    """)

    if user_input == '1':
      self.create_pin()
    elif user_input == '2':
      self.change_pin()
    elif user_input == '3':
      self.check_balance()
    elif user_input == '4':
      self.withdraw()
    else:
      exit()

  def create_pin(self):
    user_pin = input('Enter your pin : ')
    self.pin = user_pin

    user_balance = int(input('Enter balance : '))
    self.balance = user_balance

    print('pin created successfully')
    self.menu()

  def change_pin(self):
    old_pin = input('Enter old pin : ')
    if old_pin == self.pin:
      new_pin = input("Enter new pin : ")
      self.pin = new_pin
      print("pin changed successfully")
      self.menu()
    else:
      print("you entered wrong pin")
      self.menu()

  def check_balance(self):
    user_pin = input("Enter your pin : ")
    if user_pin == self.pin:
      print("Your balance is ", self.balance)
    else:
      print("you entered wrong pin")
    self.menu()

  def withdraw(self):
    user_pin = input("Enter your pin : ")
    if user_pin == self.pin:
      amount = int(input("Enter your amount to withdraw : "))
      if self.balance >= amount:
        self.balance = self.balance - amount
        print("Withdrawl Successful, remaining balance = ", self.balance)
      else:
        print("Insufficient balance, Available balance = ", self.balance)
    else:
      print("You entered wrong pin")
    self.menu()

# %%
obj = Atm()
# Out:
#     Hi how can I help you?
#     1. Press 1 to create pin
#     2. Press 2 to change pin
#     3. Press 3 to check balance
#     4. Press 4 to withdraw
#     5. Anything else to exit
#     1
# Enter your pin : 1229
# Enter balance : 10000
# pin created successfully
#
#     Hi how can I help you?
#     1. Press 1 to create pin
#     2. Press 2 to change pin
#     3. Press 3 to check balance
#     4. Press 4 to withdraw
#     5. Anything else to exit
#     4
# Enter your pin : 2345
# You entered wrong pin
#
#     Hi how can I help you?
#     1. Press 1 to create pin
#     2. Press 2 to change pin
#     3. Press 3 to check balance
#     4. Press 4 to withdraw
#     5. Anything else to exit
#     4
# Enter your pin : 1229
# Enter your amount to withdraw : 8000
# Withdrawl Successful, remaining balance =  2000
#
#     Hi how can I help you?
#     1. Press 1 to create pin
#     2. Press 2 to change pin
#     3. Press 3 to check balance
#     4. Press 4 to withdraw
# ...

# %%
# Method VS Function
L = [1,2,3]
len(L) # function -> bcos it is outside the list class
L.append(4) # method -> bcos it is inside the list class
L
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# Magic Method/Dunder Method -> Has its own superpowers

# %%
class Temp:
  def __init__(self):
    print("hello")

o = Temp()
# Out:
# hello

# %% [markdown]
# - Golden Rule of OOPS -> The Object of a class is the only one who can access the members(methods and attributes) of that class.
# - self is nothing but object of the current class.
# - When we make a new object then we actually pass the object as parameter named self.
# - To call one method in other method we cannot access it directly, we need to use self : self.methodname()

# %%
class selftest:
  def __init__(self):
    print(id(self))
  def printHello():
    print("hello")

# %%
obj = selftest()
# Out:
# 140235230281216

# %% [markdown]
# Here we can see that the id of self and the id of object both are exactly same, means self is nothing but object.

# %%
id(obj)
# Out:
# 140235230281216

# %%
obj.printHello()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_802/3685179450.py in <cell line: 0>()
# ----> 1 obj.printHello()
#
# TypeError: selftest.printHello() takes 0 positional arguments but 1 was given

# %% [markdown]
# ## **Creating our own Datatype : Fraction**

# %%
class Fraction:
  # Paramererized Constructor
  def __init__(self,x,y):
    self.num = x
    self.den = y

  def __str__(self):
    return '{}/{}'.format(self.num,self.den)

  def __add__(self,other):
    new_num = self.num * other.den + other.num * self.den
    new_den = self.den * other.den
    return "{}/{}".format(new_num,new_den)

  def __sub__(self,other):
    new_num = self.num * other.den - other.num * self.den
    new_den = self.den * other.den
    return "{}/{}".format(new_num,new_den)

  def __mul__(self,other):
    new_num = self.num * other.num
    new_den = self.den * other.den
    return "{}/{}".format(new_num,new_den)

  def __truediv__(self,other):
    new_num = self.num * other.den
    new_den = self.den * other.num
    return "{}/{}".format(new_num,new_den)

  def convert_to_decimal(self):
    return self.num/self.den

# %%
fr1 = Fraction(3,4)
fr2 = Fraction(1,2)

# %%
print(fr1) # we need it to print 3/4 using the __str__(self) dunder method

# %%
print(fr1)
# Out:
# 3/4

# %%
print(fr1 + fr2)
print(fr1 - fr2)
print(fr1 * fr2)
print(fr1 / fr2)
print(fr1.convert_to_decimal())
print(fr2.convert_to_decimal())
# Out:
# 10/8
# 2/8
# 3/8
# 6/4
# 0.75
# 0.5
